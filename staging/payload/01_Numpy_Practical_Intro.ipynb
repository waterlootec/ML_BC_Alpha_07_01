# %% [markdown]
# ![wtec_logo.png](attachment:wtec_logo.png)

# %% [markdown]
# <font color='purple'>We welcome any constructive feedback to improve our content.. Please contact _GAN MOHIM (author)_ at the following address: `waterlootec<at>gmail_dot_com`</font>

# %% [markdown]
# # How does a computer understand digital photos?

# %% [markdown]
# Let's talk about pixels.

# %% [markdown]
# ## Let's take a quick fly-past over NumPy.

# %%
# !pip install Pillow

# %%
import numpy as np
import scipy.misc as misc
import matplotlib.pyplot as plt
from scipy import ndimage
from PIL import Image
from numpy import asarray

# %%
# face = misc.face()
# print(face)
# # plt.gray()
# # plt.imshow(face)
# # plt.show()

# %% [markdown]
# ## Convert the image into a NumPy Array

# %%
raccoon_image = Image.open('raccoon-2906297_960_720.jpg')

raccoon_data = asarray(raccoon_image)

print(raccoon_data.shape)

# %%
type(raccoon_data)

# %%
import sys
np.set_printoptions(threshold=sys.maxsize) # ?
print(len(raccoon_data))
print(len(raccoon_data[0]))
print(len(raccoon_data[0][0]))

# %% [markdown]
# ## Matplotlib Sneaking in Quietly to Show the Image

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(raccoon_data)

# %%
plt.show()

# %% [markdown]
# ### Cropping Images

# %%
first_half = raccoon_data[0:350,:,:]

#print(a[0])
plt.imshow(first_half)
plt.show()

# %% [markdown]
# #  <font color='red'>Your Turn!</font>
#
# 1. Change the code above to show the missing half (only).

# %%
# Your code goes below.

# %% [markdown]
# ## Making a picture look creepy!

# %%
creepy_raccoon = raccoon_data[ : , : , : ] - 5

plt.imshow(creepy_raccoon)
plt.show()

# %% [markdown]
# ## How does a computer crop an image?

# %%
(first_half, second_half) = np.split(raccoon_data,2)

# %%
plt.imshow(first_half)
plt.show()

# %%
plt.imshow(second_half)
plt.show()

# %% [markdown]
# ## Let's crop vertically

# %%
left_split, right_split = np.split(raccoon_data, 2, axis=1)

# %%
plt.imshow(left_split)
plt.show()

# %%
plt.imshow(right_split)
plt.show()

# %% [markdown]
# ## <font color='orange'>Here is a programmer who did not pay attention to his/her class.. Yikes!!</font>

# %%
plt.imshow(np.concatenate((left_split, right_split)))
plt.show()

# %% [markdown]
# #  <font color='red'>Your Turn!</font>
#
# 1. How would you fix the code?

# %%
# Your code goes below this line.
